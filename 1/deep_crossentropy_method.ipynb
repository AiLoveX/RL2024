# %% [markdown]
# # Deep Crossentropy method
#
# In this section we'll extend your CEM implementation with neural networks! You will train a multi-layer neural network to solve simple continuous state space games. __Please make sure you're done with tabular crossentropy method from the previous notebook.__
#
# ![img](https://watanimg.elwatannews.com/old_news_images/large/249765_Large_20140709045740_11.jpg)

# %%
import sys, os
if 'google.colab' in sys.modules and not os.path.exists('.setup_complete'):
    # !wget -q https://raw.githubusercontent.com/yandexdataschool/Practical_RL/master/setup_colab.sh -O- | bash
    # !touch .setup_complete

# This code creates a virtual display to draw game images on.
# It will have no effect if your machine has a monitor.
if type(os.environ.get("DISPLAY")) is not str or len(os.environ.get("DISPLAY")) == 0:
    # !bash ../xvfb start
    os.environ['DISPLAY'] = ':1'
# Out:
# /bin/bash: ../xvfb: No such file or directory

# %%
# Install gymnasium if you didn't
# !pip install gymnasium[toy_text,classic_control]
# Out:
# Requirement already satisfied: gymnasium[classic_control,toy_text] in c:\users\1\appdata\local\programs\python\python311\lib\site-packages (0.29.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\1\appdata\local\programs\python\python311\lib\site-packages (from gymnasium[classic_control,toy_text]) (1.26.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\1\appdata\local\programs\python\python311\lib\site-packages (from gymnasium[classic_control,toy_text]) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\1\appdata\local\programs\python\python311\lib\site-packages (from gymnasium[classic_control,toy_text]) (4.8.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\1\appdata\local\programs\python\python311\lib\site-packages (from gymnasium[classic_control,toy_text]) (0.0.4)
# Requirement already satisfied: pygame>=2.1.3 in c:\users\1\appdata\local\programs\python\python311\lib\site-packages (from gymnasium[classic_control,toy_text]) (2.5.2)
# DEPRECATION: omegaconf 2.0.6 has a non-standard dependency specifier PyYAML>=5.1.*. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of omegaconf or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# if you see "<classname> has no attribute .env", remove .env or update gym
env = gym.make("CartPole-v0", render_mode="rgb_array").env

env.reset()
n_actions = env.action_space.n
state_dim = env.observation_space.shape[0]

plt.imshow(env.render())
print("state vector dim =", state_dim)
print("n_actions =", n_actions)

env.close()
# Out:
# c:\Users\1\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\envs\registration.py:513: DeprecationWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.deprecation(
# state vector dim = 4
# n_actions = 2

# %% [markdown]
# # Neural Network Policy
#
# For this assignment we'll utilize the simplified neural network implementation from __[Scikit-learn](https://scikit-learn.org/stable/modules/generated/sklearn.neural_network.MLPClassifier.html)__. Here's what you'll need:
#
# * `agent.partial_fit(states, actions)` - make a single training pass over the data. Maximize the probability of :actions: from :states:
# * `agent.predict_proba(states)` - predict probabilities of all actions, a matrix of shape __[len(states), n_actions]__

# %%
from sklearn.neural_network import MLPClassifier

agent = MLPClassifier(
    hidden_layer_sizes=(20, 20),
    activation="tanh",
)

# initialize agent to the dimension of state space and number of actions
agent.partial_fit([env.reset()[0]] * n_actions, range(n_actions), range(n_actions))
# Out:
# MLPClassifier(activation='tanh', hidden_layer_sizes=(20, 20))

# %%
def generate_session(env, agent, t_max=1000):
    """
    Play a single game using agent neural network.
    Terminate when game finishes or after :t_max: steps
    """
    states, actions = [], []
    total_reward = 0

    s, _ = env.reset()

    for t in range(t_max):

        # use agent to predict a vector of action probabilities for state :s:
        probs = agent.predict_proba(s.reshape(1, -1)).reshape(-1)

        assert probs.shape == (env.action_space.n,), "make sure probabilities are a vector (hint: np.reshape)"

        # use the probabilities you predicted to pick an action
        # sample proportionally to the probabilities, don't just take the most likely action
        a = np.random.choice(np.arange(n_actions), p=probs)
        # ^-- hint: try np.random.choice

        new_s, r, terminated, truncated, _ = env.step(a)

        # record sessions like you did before
        states.append(s)
        actions.append(a)
        total_reward += r

        s = new_s
        if terminated or truncated:
            break
    return states, actions, total_reward

# %%
dummy_states, dummy_actions, dummy_reward = generate_session(env, agent, t_max=5)
print("states:", np.stack(dummy_states))
print("actions:", dummy_actions)
print("reward:", dummy_reward)
# Out:
# states: [[ 4.2027526e-02  3.0990565e-04  1.3993597e-02 -8.8442466e-04]
#  [ 4.2033724e-02 -1.9500992e-01  1.3975908e-02  2.9618061e-01]
#  [ 3.8133524e-02 -8.9956833e-05  1.9899521e-02  7.9380041e-03]
#  [ 3.8131725e-02  1.9474104e-01  2.0058280e-02 -2.7840054e-01]
#  [ 4.2026546e-02 -6.6123257e-04  1.4490269e-02  2.0540630e-02]]
# actions: [0, 1, 1, 0, 1]
# reward: 5.0

# %% [markdown]
# ### CEM steps
# Deep CEM uses exactly the same strategy as the regular CEM, so you can copy your function code from previous notebook.
#
# The only difference is that now each observation is not a number but a `float32` vector.

# %%
def select_elites(states_batch, actions_batch, rewards_batch, percentile=50):
    """
    Select states and actions from games that have rewards >= percentile
    :param states_batch: list of lists of states, states_batch[session_i][t]
    :param actions_batch: list of lists of actions, actions_batch[session_i][t]
    :param rewards_batch: list of rewards, rewards_batch[session_i]

    :returns: elite_states,elite_actions, both 1D lists of states and respective actions from elite sessions

    Please return elite states and actions in their original order
    [i.e. sorted by session number and timestep within session]

    If you are confused, see examples below. Please don't assume that states are integers
    (they will become different later).
    """

    reward_threshold = np.percentile(rewards_batch, percentile)
    elite_ids = list(filter(lambda idx: rewards_batch[idx] >= reward_threshold, range(len(rewards_batch))))
    elite_states = sum((states_batch[_] for _ in elite_ids), [])
    elite_actions = sum((actions_batch[_] for _ in elite_ids), [])

    return elite_states, elite_actions

# %% [markdown]
# # Training loop
# Generate sessions, select N best and fit to those.

# %%
from IPython.display import clear_output


def show_progress(rewards_batch, log, percentile, reward_range=[-990, +10]):
    """
    A convenience function that displays training progress.
    No cool math here, just charts.
    """

    mean_reward = np.mean(rewards_batch)
    threshold = np.percentile(rewards_batch, percentile)
    log.append([mean_reward, threshold])

    clear_output(True)
    print("mean reward = %.3f, threshold=%.3f" % (mean_reward, threshold))
    plt.figure(figsize=[8, 4])
    plt.subplot(1, 2, 1)
    plt.plot(list(zip(*log))[0], label="Mean rewards")
    plt.plot(list(zip(*log))[1], label="Reward thresholds")
    plt.legend()
    plt.grid()

    plt.subplot(1, 2, 2)
    plt.hist(rewards_batch, range=reward_range)
    plt.vlines(
        [np.percentile(rewards_batch, percentile)],
        [0],
        [100],
        label="percentile",
        color="red",
    )
    plt.legend()
    plt.grid()

    plt.show()

# %%
n_sessions = 100
percentile = 70
log = []

for i in range(100):
    # generate new sessions
    sessions = [ generate_session(env, agent) for _ in range(n_sessions) ]
    states_batch, actions_batch, rewards_batch = zip(*sessions)

    elite_states, elite_actions = select_elites(states_batch, actions_batch, rewards_batch)

    agent.partial_fit(elite_states, elite_actions)

    show_progress(
        rewards_batch, log, percentile, reward_range=[0, np.max(rewards_batch)]
    )

    if np.mean(rewards_batch) > 190:
        print("You Win! You may stop training now via KeyboardInterrupt.")
        break
# Out:
# mean reward = 201.790, threshold=227.900
# You Win! You may stop training now via KeyboardInterrupt.

# %% [markdown]
# # Results

# %%
pip install moviepy
# Out:
# Requirement already satisfied: moviepy in c:\users\1\appdata\local\programs\python\python311\lib\site-packages (1.0.3)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in c:\users\1\appdata\local\programs\python\python311\lib\site-packages (from moviepy) (4.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in c:\users\1\appdata\local\programs\python\python311\lib\site-packages (from moviepy) (4.66.1)
# Requirement already satisfied: requests<3.0,>=2.8.1 in c:\users\1\appdata\local\programs\python\python311\lib\site-packages (from moviepy) (2.31.0)
# Requirement already satisfied: proglog<=1.0.0 in c:\users\1\appdata\local\programs\python\python311\lib\site-packages (from moviepy) (0.1.10)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\1\appdata\local\programs\python\python311\lib\site-packages (from moviepy) (1.26.1)
# Requirement already satisfied: imageio<3.0,>=2.5 in c:\users\1\appdata\local\programs\python\python311\lib\site-packages (from moviepy) (2.34.1)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in c:\users\1\appdata\local\programs\python\python311\lib\site-packages (from moviepy) (0.4.9)
# Requirement already satisfied: pillow>=8.3.2 in c:\users\1\appdata\local\programs\python\python311\lib\site-packages (from imageio<3.0,>=2.5->moviepy) (10.1.0)
# Requirement already satisfied: setuptools in c:\users\1\appdata\local\programs\python\python311\lib\site-packages (from imageio-ffmpeg>=0.2.0->moviepy) (65.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\1\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\1\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\1\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\1\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (2023.7.22)
# Requirement already satisfied: colorama in c:\users\1\appdata\local\programs\python\python311\lib\site-packages (from tqdm<5.0,>=4.11.2->moviepy) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: omegaconf 2.0.6 has a non-standard dependency specifier PyYAML>=5.1.*. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of omegaconf or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
# Record sessions

from gymnasium.wrappers import RecordVideo

with RecordVideo(
    env=gym.make("CartPole-v0", render_mode="rgb_array"),
    video_folder="./videos",
    episode_trigger=lambda episode_number: True,
) as env_monitor:
    sessions = [generate_session(env_monitor, agent) for _ in range(100)]
# Out:
# c:\Users\1\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\envs\registration.py:513: DeprecationWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.deprecation(
# c:\Users\1\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\wrappers\record_video.py:94: UserWarning: WARN: Overwriting existing videos at e:\RL\1\videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-0.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-0.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-1.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-1.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-1.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-2.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-2.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-2.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-3.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-3.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-3.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-4.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-4.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-4.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-5.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-5.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-5.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-6.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-6.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-6.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-7.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-7.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-7.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-8.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-8.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-8.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-9.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-9.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-9.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-10.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-10.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-10.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-11.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-11.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-11.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-12.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-12.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-12.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-13.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-13.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-13.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-14.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-14.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-14.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-15.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-15.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-15.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-16.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-16.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-16.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-17.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-17.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-17.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-18.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-18.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-18.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-19.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-19.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-19.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-20.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-20.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-20.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-21.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-21.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-21.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-22.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-22.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-22.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-23.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-23.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-23.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-24.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-24.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-24.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-25.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-25.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-25.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-26.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-26.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-26.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-27.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-27.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-27.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-28.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-28.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-28.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-29.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-29.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-29.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-30.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-30.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-30.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-31.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-31.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-31.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-32.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-32.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-32.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-33.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-33.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-33.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-34.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-34.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-34.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-35.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-35.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-35.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-36.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-36.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-36.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-37.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-37.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-37.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-38.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-38.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-38.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-39.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-39.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-39.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-40.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-40.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-40.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-41.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-41.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-41.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-42.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-42.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-42.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-43.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-43.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-43.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-44.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-44.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-44.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-45.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-45.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-45.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-46.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-46.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-46.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-47.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-47.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-47.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-48.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-48.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-48.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-49.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-49.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-49.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-50.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-50.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-50.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-51.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-51.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-51.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-52.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-52.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-52.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-53.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-53.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-53.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-54.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-54.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-54.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-55.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-55.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-55.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-56.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-56.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-56.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-57.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-57.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-57.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-58.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-58.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-58.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-59.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-59.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-59.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-60.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-60.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-60.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-61.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-61.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-61.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-62.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-62.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-62.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-63.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-63.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-63.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-64.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-64.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-64.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-65.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-65.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-65.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-66.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-66.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-66.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-67.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-67.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-67.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-68.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-68.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-68.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-69.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-69.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-69.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-70.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-70.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-70.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-71.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-71.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-71.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-72.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-72.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-72.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-73.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-73.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-73.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-74.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-74.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-74.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-75.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-75.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-75.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-76.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-76.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-76.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-77.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-77.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-77.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-78.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-78.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-78.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-79.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-79.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-79.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-80.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-80.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-80.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-81.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-81.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-81.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-82.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-82.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-82.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-83.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-83.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-83.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-84.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-84.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-84.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-85.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-85.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-85.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-86.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-86.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-86.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-87.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-87.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-87.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-88.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-88.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-88.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-89.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-89.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-89.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-90.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-90.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-90.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-91.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-91.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-91.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-92.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-92.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-92.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-93.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-93.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-93.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-94.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-94.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-94.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-95.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-95.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-95.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-96.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-96.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-96.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-97.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-97.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-97.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-98.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-98.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-98.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-99.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-99.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-99.mp4

# %%
# Show video. This may not work in some setups. If it doesn't
# work for you, you can download the videos and view them locally.

from pathlib import Path
from base64 import b64encode
from IPython.display import HTML

video_paths = sorted([s for s in Path("videos").iterdir() if s.suffix == ".mp4"])
video_path = video_paths[-1]  # You can also try other indices

if "google.colab" in sys.modules:
    # https://stackoverflow.com/a/57378660/1214547
    with video_path.open("rb") as fp:
        mp4 = fp.read()
    data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
else:
    data_url = str(video_path)

HTML(
    """
<video width="640" height="480" controls>
  <source src="{}" type="video/mp4">
</video>
""".format(
        data_url
    )
)
# Out:
# <video width="640" height="480" controls>
#   <source src="videos\rl-video-episode-99.mp4" type="video/mp4">
# </video>

# %% [markdown]
# # Homework part I
#
# ### Tabular crossentropy method
#
# You may have noticed that the taxi problem quickly converges from -100 to a near-optimal score and then descends back into -50/-100. This is in part because the environment has some innate randomness. Namely, the starting points of passenger/driver change from episode to episode.
#
# ### Tasks
# - __1.1__ (2 pts) Find out how the algorithm performance changes if you use a different `percentile` and/or `n_sessions`. Provide here some figures so we can see how the hyperparameters influence the performance.
# - __1.2__ (1 pts) Tune the algorithm to end up with positive average score.
#
# It's okay to modify the existing code.

# %% [markdown]
# Copy the taxi problem from `crossentropy_method.ipynb`

# %%
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt

env = gym.make("Taxi-v3", render_mode="rgb_array")
print(env.reset(seed=0))
plt.imshow(env.render())
# Out:
# (314, {'prob': 1.0, 'action_mask': array([1, 1, 0, 0, 0, 0], dtype=int8)})

# %%
n_states = env.observation_space.n
n_actions = env.action_space.n

print(f"n_states={n_states}, n_actions={n_actions}")
# Out:
# n_states=500, n_actions=6

# %%
def initialize_policy(n_states, n_actions):
    policy = np.full((n_states, n_actions), 1.0 / n_actions)

    return policy


policy = initialize_policy(n_states, n_actions)

# %%
def generate_session(env, policy, t_max=10**4):
    states, actions = [], []
    total_reward = 0.0

    s, _ = env.reset()

    for t in range(t_max):
        # Hint: you can use np.random.choice for sampling action
        # https://numpy.org/doc/stable/reference/random/generated/numpy.random.choice.html

        a = np.random.choice(n_actions, p=policy[s])

        new_s, r, terminated, truncated, _ = env.step(a)

        # Record information we just got from the environment.
        states.append(s)
        actions.append(a)
        total_reward += r

        s = new_s
        if terminated or truncated:
            break

    return states, actions, total_reward

# %%
def select_elites(states_batch, actions_batch, rewards_batch, percentile):
    reward_threshold = np.percentile(rewards_batch, percentile)
    elite_ids = list(filter(lambda idx: rewards_batch[idx] >= reward_threshold, range(len(rewards_batch))))
    elite_states = sum((states_batch[_] for _ in elite_ids), [])
    elite_actions = sum((actions_batch[_] for _ in elite_ids), [])

    return elite_states, elite_actions

# %%
def get_new_policy(elite_states, elite_actions):
    new_policy = np.zeros([n_states, n_actions])

    for idx, state in enumerate(elite_states):
        new_policy[state, elite_actions[idx]] += 1
    for idx in range(n_states):
        norm = np.sum(new_policy[idx])
        if norm == 0:
            new_policy[idx] = np.full(n_actions, 1/6)
        else:
            new_policy[idx] /= norm

    return new_policy

# %%
from IPython.display import clear_output


def show_progress(rewards_batch, log, percentile):
    mean_reward = np.mean(rewards_batch)
    threshold = np.percentile(rewards_batch, percentile)
    log.append([mean_reward, threshold])

    plt.figure(figsize=[8, 4])
    plt.subplot(1, 2, 1)
    plt.plot(list(zip(*log))[0], label="Mean rewards")
    plt.plot(list(zip(*log))[1], label="Reward thresholds")
    plt.legend()
    plt.grid()

    plt.subplot(1, 2, 2)
    plt.hist(rewards_batch)
    plt.vlines(
        [np.percentile(rewards_batch, percentile)],
        [0],
        [100],
        label="percentile",
        color="red",
    )
    plt.legend()
    plt.grid()
    clear_output(True)
    print("mean reward = %.3f, threshold=%.3f" % (mean_reward, threshold))
    plt.show()

# %%
# reset policy just in case
policy = initialize_policy(n_states, n_actions)

# %%
from tqdm import tqdm

def training_loop(n_sessions=250, percentile=50):
    learning_rate = 0.5
    policy = initialize_policy(n_states, n_actions)
    mean_rewards = []
    for _ in tqdm(range(100), leave=False):
        sessions = [ generate_session(env, policy) for _ in range(n_sessions) ]
        states_batch, actions_batch, rewards_batch = zip(*sessions)
        elite_states, elite_actions = select_elites(states_batch, actions_batch, rewards_batch, percentile)
        new_policy = get_new_policy(elite_states, elite_actions)
        policy = learning_rate * new_policy + (1 - learning_rate) * policy
        mean_rewards.append(np.mean(rewards_batch))
    return mean_rewards

# %%
def show_progress_multiple(mean_rewards_data, legend_data):
    plt.figure(figsize=[8, 4])
    plt.subplot(1, 1, 1)
    for mean_rewards, legend in zip(mean_rewards_data, legend_data):
        plt.plot(mean_rewards, label=legend)
    plt.legend()
    plt.grid()
    plt.show()

# %%
mean_rewards_data = []
legend_data = []

for n_sessions in [50, 150, 250, 350, 450, 650, 850, 1000]:
    mean_rewards_data.append(training_loop(n_sessions=n_sessions))
    legend_data.append(f"n_sessions={n_sessions}")

show_progress_multiple(mean_rewards_data, legend_data)

# %%
mean_rewards_data = []
legend_data = []

for percentile in [5, 15, 25, 35, 50, 65, 75, 85, 95]:
    mean_rewards_data.append(training_loop(percentile=percentile))
    legend_data.append(f"percentile={percentile}")

show_progress_multiple(mean_rewards_data, legend_data)

# %%
n_sessions = 250
percentile = 15
learning_rate = 0.5
policy = initialize_policy(n_states, n_actions)
log = []
for _ in tqdm(range(1000)):
    sessions = [ generate_session(env, policy) for _ in range(n_sessions) ]
    states_batch, actions_batch, rewards_batch = zip(*sessions)
    elite_states, elite_actions = select_elites(states_batch, actions_batch, rewards_batch, percentile)
    new_policy = get_new_policy(elite_states, elite_actions)
    policy = learning_rate * new_policy + (1 - learning_rate) * policy
    show_progress(rewards_batch, log, percentile)
    if np.mean(rewards_batch) > 0:
        print("Done!")
        break
# Out:
# mean reward = 0.072, threshold=-4.000
#  67%|██████▋   | 667/1000 [11:06<05:32,  1.00it/s]
# Done!

# %% [markdown]
# # Homework part II
#
# ### Deep crossentropy method
#
# By this moment, you should have got enough score on [CartPole-v0](https://gymnasium.farama.org/environments/classic_control/cart_pole/) to consider it solved (see the link). It's time to try something harder.
#
# * if you have any trouble with CartPole-v0 and feel stuck, feel free to ask us or your peers for help.
#
# ### Tasks
#
# * __2.1__ (3 pts) Pick one of environments: `MountainCar-v0` or `LunarLander-v2`.
#   * For MountainCar, get average reward of __at least -150__
#   * For LunarLander, get average reward of __at least +50__
#
# See the tips section below, it's kinda important.
# __Note:__ If your agent is below the target score, you'll still get some of the points depending on the result, so don't be afraid to submit it.
#
#
# * __2.2__ (up to 6 pts) Devise a way to speed up training against the default version
#   * Obvious improvement: use [`joblib`](https://joblib.readthedocs.io/en/latest/). However, note that you will probably need to spawn a new environment in each of the workers instead of passing it via pickling. (2 pts)
#   * Try re-using samples from 3-5 last iterations when computing threshold and training. (2 pts)
#   * Obtain __-100__ at `MountainCar-v0` or __+200__ at `LunarLander-v2` (2 pts). Feel free to experiment with hyperparameters, architectures, schedules etc.
#
# __Please list what you did in Anytask submission form__. This reduces probability that somebody misses something.
#
#
# ### Tips
# * Gymnasium pages: [MountainCar](https://gymnasium.farama.org/environments/classic_control/mountain_car/), [LunarLander](https://gymnasium.farama.org/environments/box2d/lunar_lander/)
# * Sessions for MountainCar may last for 10k+ ticks. Make sure ```t_max``` param is at least 10k.
#  * Also it may be a good idea to cut rewards via ">" and not ">=". If 90% of your sessions get reward of -10k and 10% are better, than if you use percentile 20% as threshold, R >= threshold __fails to cut off bad sessions__ while R > threshold works alright.
# * _issue with gym_: Some versions of gym limit game time by 200 ticks. This will prevent cem training in most cases. Make sure your agent is able to play for the specified __t_max__, and if it isn't, try `env = gym.make("MountainCar-v0").env` or otherwise get rid of TimeLimit wrapper.
# * If you use old _swig_ lib for LunarLander-v2, you may get an error. See this [issue](https://github.com/openai/gym/issues/100) for solution.
# * If it doesn't train, it's a good idea to plot reward distribution and record sessions: they may give you some clue. If they don't, call course staff :)
# * 20-neuron network is probably not enough, feel free to experiment.
#
# You may find the following snippet useful:

# %%
def visualize_mountain_car(env, agent):
    # Compute policy for all possible x and v (with discretization)
    xs = np.linspace(env.min_position, env.max_position, 100)
    vs = np.linspace(-env.max_speed, env.max_speed, 100)

    grid = np.dstack(np.meshgrid(xs, vs[::-1])).transpose(1, 0, 2)
    grid_flat = grid.reshape(len(xs) * len(vs), 2)
    probs = (
        agent.predict_proba(grid_flat).reshape(len(xs), len(vs), 3).transpose(1, 0, 2)
    )

    # # The above code is equivalent to the following:
    # probs = np.empty((len(vs), len(xs), 3))
    # for i, v in enumerate(vs[::-1]):
    #     for j, x in enumerate(xs):
    #         probs[i, j, :] = agent.predict_proba([[x, v]])[0]

    # Draw policy
    f, ax = plt.subplots(figsize=(7, 7))
    ax.imshow(
        probs,
        extent=(env.min_position, env.max_position, -env.max_speed, env.max_speed),
        aspect="auto",
    )
    ax.set_title("Learned policy: red=left, green=nothing, blue=right")
    ax.set_xlabel("position (x)")
    ax.set_ylabel("velocity (v)")

    # Sample a trajectory and draw it
    states, actions, _ = generate_session(env, agent)
    states = np.array(states)
    ax.plot(states[:, 0], states[:, 1], color="white")

    # Draw every 3rd action from the trajectory
    for (x, v), a in zip(states[::3], actions[::3]):
        if a == 0:
            plt.arrow(x, v, -0.1, 0, color="white", head_length=0.02)
        elif a == 2:
            plt.arrow(x, v, 0.1, 0, color="white", head_length=0.02)


# with gym.make("MountainCar-v0", render_mode="rgb_arrary").env as env:
#     visualize_mountain_car(env, agent)

# %%
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# if you see "<classname> has no attribute .env", remove .env or update gym
env = gym.make("MountainCar-v0", render_mode="rgb_array").env

env.reset()
n_actions = env.action_space.n
state_dim = env.observation_space.shape[0]

plt.imshow(env.render())
print("state vector dim =", state_dim)
print("n_actions =", n_actions)

env.close()
# Out:
# state vector dim = 2
# n_actions = 3

# %%
from sklearn.neural_network import MLPClassifier

agent = MLPClassifier(
    hidden_layer_sizes=(50, 100, 50),
    activation="tanh",
)

# initialize agent to the dimension of state space and number of actions
agent.partial_fit([env.reset()[0]] * n_actions, range(n_actions), range(n_actions))
# Out:
# MLPClassifier(activation='tanh', hidden_layer_sizes=(50, 100, 50))

# %%
def generate_session(env, agent, t_max=10000):
    """
    Play a single game using agent neural network.
    Terminate when game finishes or after :t_max: steps
    """
    states, actions = [], []
    total_reward = 0

    s, _ = env.reset()

    for t in range(t_max):

        # use agent to predict a vector of action probabilities for state :s:
        probs = agent.predict_proba(s.reshape(1, -1)).reshape(-1)

        assert probs.shape == (env.action_space.n,), "make sure probabilities are a vector (hint: np.reshape)"

        # use the probabilities you predicted to pick an action
        # sample proportionally to the probabilities, don't just take the most likely action
        a = np.random.choice(np.arange(n_actions), p=probs)
        # ^-- hint: try np.random.choice

        new_s, r, terminated, truncated, _ = env.step(a)

        # record sessions like you did before
        states.append(s)
        actions.append(a)
        total_reward += r

        s = new_s
        if terminated or truncated:
            break
    return states, actions, total_reward

# %%
def select_elites(states_batch, actions_batch, rewards_batch, percentile=50):
    """
    Select states and actions from games that have rewards > percentile
    :param states_batch: list of lists of states, states_batch[session_i][t]
    :param actions_batch: list of lists of actions, actions_batch[session_i][t]
    :param rewards_batch: list of rewards, rewards_batch[session_i]

    :returns: elite_states,elite_actions, both 1D lists of states and respective actions from elite sessions

    Please return elite states and actions in their original order
    [i.e. sorted by session number and timestep within session]

    If you are confused, see examples below. Please don't assume that states are integers
    (they will become different later).
    """

    reward_threshold = np.percentile(rewards_batch, percentile)
    elite_ids = list(filter(lambda idx: rewards_batch[idx] > reward_threshold, range(len(rewards_batch))))
    elite_states = sum((states_batch[_] for _ in elite_ids), [])
    elite_actions = sum((actions_batch[_] for _ in elite_ids), [])

    return elite_states, elite_actions

# %%
from IPython.display import clear_output


def show_progress(rewards_batch, log, percentile, reward_range=[-990, +10]):
    """
    A convenience function that displays training progress.
    No cool math here, just charts.
    """

    mean_reward = np.mean(rewards_batch)
    threshold = np.percentile(rewards_batch, percentile)
    log.append([mean_reward, threshold])

    clear_output(True)
    print("mean reward = %.3f, threshold=%.3f" % (mean_reward, threshold))
    plt.figure(figsize=[8, 4])
    plt.subplot(1, 2, 1)
    plt.plot(list(zip(*log))[0], label="Mean rewards")
    plt.plot(list(zip(*log))[1], label="Reward thresholds")
    plt.legend()
    plt.grid()

    plt.subplot(1, 2, 2)
    plt.hist(rewards_batch, range=reward_range)
    plt.vlines(
        [np.percentile(rewards_batch, percentile)],
        [0],
        [100],
        label="percentile",
        color="red",
    )
    plt.legend()
    plt.grid()

    plt.show()

# %%
from joblib import Parallel, delayed


env = gym.make("MountainCar-v0", render_mode="rgb_array").env
agent = MLPClassifier(
    hidden_layer_sizes=(50, 100, 50),
    activation="tanh",
)
agent.partial_fit([env.reset()[0]] * n_actions, range(n_actions), range(n_actions))

n_sessions = 150
percentile = 80
log = []

while True:
    # generate new sessions
    sessions = Parallel(n_jobs=12)(delayed(generate_session)(env, agent) for _ in range(n_sessions))

    # states_batch, actions_batch, rewards_batch = map(np.array, zip(*sessions))
    states_batch, actions_batch, rewards_batch = zip(*sessions)

    elite_states, elite_actions = select_elites(states_batch, actions_batch, rewards_batch, percentile)

    agent.partial_fit(elite_states, elite_actions)

    show_progress(
        rewards_batch, log, percentile, reward_range=[np.min(rewards_batch), np.max(rewards_batch)]
    )

    if np.mean(rewards_batch) > -150:
        break
# Out:
# mean reward = -145.707, threshold=-140.000

# %%
# Record sessions

from gymnasium.wrappers import RecordVideo

with RecordVideo(
    env=gym.make("MountainCar-v0", render_mode="rgb_array"),
    video_folder="./videos",
    episode_trigger=lambda episode_number: True,
) as env_monitor:
    sessions = [generate_session(env_monitor, agent) for _ in range(100)]
# Out:
# c:\Users\1\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\wrappers\record_video.py:94: UserWarning: WARN: Overwriting existing videos at e:\RL\1\videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-0.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-0.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-1.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-1.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-1.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-2.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-2.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-2.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-3.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-3.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-3.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-4.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-4.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-4.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-5.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-5.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-5.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-6.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-6.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-6.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-7.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-7.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-7.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-8.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-8.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-8.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-9.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-9.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-9.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-10.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-10.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-10.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-11.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-11.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-11.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-12.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-12.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-12.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-13.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-13.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-13.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-14.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-14.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-14.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-15.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-15.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-15.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-16.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-16.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-16.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-17.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-17.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-17.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-18.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-18.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-18.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-19.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-19.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-19.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-20.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-20.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-20.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-21.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-21.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-21.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-22.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-22.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-22.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-23.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-23.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-23.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-24.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-24.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-24.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-25.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-25.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-25.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-26.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-26.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-26.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-27.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-27.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-27.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-28.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-28.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-28.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-29.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-29.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-29.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-30.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-30.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-30.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-31.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-31.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-31.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-32.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-32.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-32.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-33.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-33.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-33.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-34.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-34.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-34.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-35.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-35.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-35.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-36.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-36.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-36.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-37.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-37.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-37.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-38.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-38.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-38.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-39.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-39.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-39.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-40.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-40.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-40.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-41.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-41.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-41.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-42.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-42.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-42.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-43.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-43.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-43.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-44.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-44.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-44.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-45.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-45.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-45.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-46.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-46.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-46.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-47.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-47.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-47.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-48.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-48.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-48.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-49.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-49.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-49.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-50.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-50.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-50.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-51.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-51.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-51.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-52.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-52.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-52.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-53.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-53.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-53.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-54.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-54.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-54.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-55.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-55.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-55.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-56.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-56.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-56.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-57.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-57.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-57.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-58.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-58.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-58.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-59.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-59.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-59.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-60.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-60.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-60.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-61.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-61.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-61.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-62.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-62.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-62.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-63.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-63.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-63.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-64.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-64.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-64.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-65.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-65.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-65.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-66.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-66.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-66.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-67.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-67.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-67.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-68.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-68.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-68.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-69.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-69.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-69.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-70.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-70.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-70.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-71.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-71.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-71.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-72.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-72.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-72.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-73.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-73.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-73.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-74.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-74.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-74.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-75.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-75.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-75.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-76.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-76.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-76.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-77.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-77.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-77.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-78.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-78.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-78.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-79.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-79.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-79.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-80.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-80.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-80.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-81.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-81.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-81.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-82.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-82.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-82.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-83.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-83.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-83.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-84.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-84.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-84.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-85.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-85.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-85.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-86.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-86.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-86.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-87.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-87.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-87.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-88.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-88.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-88.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-89.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-89.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-89.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-90.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-90.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-90.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-91.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-91.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-91.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-92.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-92.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-92.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-93.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-93.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-93.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-94.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-94.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-94.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-95.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-95.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-95.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-96.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-96.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-96.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-97.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-97.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-97.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-98.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-98.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-98.mp4
# Moviepy - Building video e:\RL\1\videos\rl-video-episode-99.mp4.
# Moviepy - Writing video e:\RL\1\videos\rl-video-episode-99.mp4
# Moviepy - Done !
# Moviepy - video ready e:\RL\1\videos\rl-video-episode-99.mp4

# %%
# Show video. This may not work in some setups. If it doesn't
# work for you, you can download the videos and view them locally.

from pathlib import Path
from base64 import b64encode
from IPython.display import HTML

video_paths = sorted([s for s in Path("videos").iterdir() if s.suffix == ".mp4"])
video_path = video_paths[-1]  # You can also try other indices

data_url = str(video_path)

HTML(
    """
<video width="640" height="480" controls>
  <source src="{}" type="video/mp4">
</video>
""".format(
        data_url
    )
)
# Out:
# <video width="640" height="480" controls>
#   <source src="videos\rl-video-episode-99.mp4" type="video/mp4">
# </video>

# %%
with gym.make("MountainCar-v0", render_mode="rgb_arrary").env as env:
    visualize_mountain_car(env, agent)
# Out:
# c:\Users\1\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\envs\registration.py:788: UserWarning: WARN: The environment is being initialised with render_mode='rgb_arrary' that is not in the possible render_modes (['human', 'rgb_array']).
#   logger.warn(
# c:\Users\1\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.min_position to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.min_position` for environment variables or `env.get_wrapper_attr('min_position')` that will search the reminding wrappers.
#   logger.warn(
# c:\Users\1\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.max_position to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.max_position` for environment variables or `env.get_wrapper_attr('max_position')` that will search the reminding wrappers.
#   logger.warn(
# c:\Users\1\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.max_speed to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.max_speed` for environment variables or `env.get_wrapper_attr('max_speed')` that will search the reminding wrappers.
#   logger.warn(
# c:\Users\1\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.min_position to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.min_position` for environment variables or `env.get_wrapper_attr('min_position')` that will search the reminding wrappers.
#   logger.warn(
# c:\Users\1\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.max_position to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.max_position` for environment variables or `env.get_wrapper_attr('max_position')` that will search the reminding wrappers.
#   logger.warn(
# c:\Users\1\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.max_speed to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.max_speed` for environment variables or `env.get_wrapper_attr('max_speed')` that will search the reminding wrappers.
#   logger.warn(

# %% [markdown]
# ### Bonus tasks
#
# * __2.3 bonus__ (2 pts) Try to find a network architecture and training params that solve __both__ environments above (_Points depend on implementation. If you attempted this task, please mention it in Anytask submission._)
#
# * __2.4 bonus__ (4 pts) Solve continuous action space task with `MLPRegressor` or similar.
#   * Since your agent only predicts the "expected" action, you will have to add noise to ensure exploration.
#   * Choose one of [MountainCarContinuous-v0](https://gymnasium.farama.org/environments/classic_control/mountain_car_continuous/) (90+ pts to solve), [LunarLanderContinuous-v2](https://gymnasium.farama.org/environments/box2d/lunar_lander/) (`env = gym.make("LunarLander-v2", continuous=True)`)(200+ pts to solve)
#   * 4 points for solving. Slightly less for getting some results below solution threshold. Note that discrete and continuous environments may have slightly different rules, aside from action spaces.
